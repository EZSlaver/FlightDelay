# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./Data/On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2019_1.csv")
df.head()
# Out:
# /home/erez/shared_venv_3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (48,69,76,77,84,85) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate Reporting_Airline  \
# 0  2019        1      1           4          5  2019-01-04                OO
# 1  2019        1      1           4          5  2019-01-04                OO
# 2  2019        1      1           4          5  2019-01-04                OO
# 3  2019        1      1           4          5  2019-01-04                OO
# 4  2019        1      1           4          5  2019-01-04                OO
#
#    DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline Tail_Number  ...  \
# 0                     20304                          OO      N945SW  ...
# 1                     20304                          OO      N932SW  ...
# ...

# %%
div_info_cols = [col for col in df.columns if col.startswith('Div') and col != 'Diverted']
df.drop(div_info_cols, axis = 1, inplace = True)
df.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate Reporting_Airline  \
# 0  2019        1      1           4          5  2019-01-04                OO
# 1  2019        1      1           4          5  2019-01-04                OO
# 2  2019        1      1           4          5  2019-01-04                OO
# 3  2019        1      1           4          5  2019-01-04                OO
# 4  2019        1      1           4          5  2019-01-04                OO
#
#    DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline Tail_Number  ...  \
# 0                     20304                          OO      N945SW  ...
# 1                     20304                          OO      N932SW  ...
# 2                     20304                          OO      N932SW  ...
# 3                     20304                          OO      N916SW  ...
# 4                     20304                          OO      N107SY  ...
#
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583985 entries, 0 to 583984
# Data columns (total 65 columns):
# Year                               583985 non-null int64
# Quarter                            583985 non-null int64
# Month                              583985 non-null int64
# DayofMonth                         583985 non-null int64
# DayOfWeek                          583985 non-null int64
# FlightDate                         583985 non-null object
# Reporting_Airline                  583985 non-null object
# DOT_ID_Reporting_Airline           583985 non-null int64
# IATA_CODE_Reporting_Airline        583985 non-null object
# Tail_Number                        581442 non-null object
# Flight_Number_Reporting_Airline    583985 non-null int64
# OriginAirportID                    583985 non-null int64
# OriginAirportSeqID                 583985 non-null int64
# OriginCityMarketID                 583985 non-null int64
# ...

# %%
df.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate Reporting_Airline  \
# 0  2019        1      1           4          5  2019-01-04                OO
# 1  2019        1      1           4          5  2019-01-04                OO
# 2  2019        1      1           4          5  2019-01-04                OO
# 3  2019        1      1           4          5  2019-01-04                OO
# 4  2019        1      1           4          5  2019-01-04                OO
#
#    DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline  \
# 0                     20304                          OO
# 1                     20304                          OO
# 2                     20304                          OO
# 3                     20304                          OO
# 4                     20304                          OO
#
#    Flight_Number_Reporting_Airline  ...  CRSDepTime  DepTimeBlk  CRSArrTime  \
# 0                             5657  ...        1400   1400-1459        1510
# ...
